# %%
df1 = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",header='true',inferSchema='true')
##df1.write.format("delta").saveAsTable("default.mobile_os_usage")
spark.sql("update default.mobile_os_usage set _c1 = upper(_c1)")
spark.sql("select * from default.mobile_os_usage").show()

# %%
# %pip install pandas

import pandas as pd

df1 = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
df1.display()

# %%
# %sh echo "Magic commands tasks completed"
