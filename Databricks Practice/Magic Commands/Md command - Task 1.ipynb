# %% [markdown]
# $$
# \Huge \textcolor{DarkBlue}{\textbf{DataBricks Notebook Learning}}
# $$
#
# $${\color{RoyalBlue}\textbf{Markdown command Learning}}$$
#
# $${\color{Teal}\textit{Sooriya Devi}}$$
#
# ![Image2.jpg](https://fpimages.withfloats.com/actual/6936e213e40c3ddda3969dd0.jpeg)
#
# $${\color{green}\textbf{'md: allows you to write markdown text to design the notebook.'}}$$
