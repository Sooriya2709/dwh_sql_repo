# %% [markdown]
# <h1>DataBricks Notebook<h1>
# <h2>Sample Programs<h2>
# <h3>Program 1<h3>
#
#
# $${\color{green}\textbf{'md: allows you to write markdown text to design the notebook.'}}$$
#
# https://share.google/i5x6t4Vpfmf5CHkHa

# %% [markdown]
# <h3> Program 2 <h3>
#
# $${\color{Maroon}\textbf{'run: runs a Python file or a notebook.'}}$$
