# %%
df1.write.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/",sep=',',header=True,mode='overwrite')

# %%
df2 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage.tsv",sep='\t',header=True)
df2.write.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/",sep='\t',header=True,mode='append')

# %%
df3 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower.log",sep='|',header=True)
df3.write.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/",sep='|',header=True,mode='append')
df3.show(1)

# %%
df1 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer.csv",sep=',')
df1.write.json("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/",mode='overwrite')
display(df1)

# %%
df2 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage.tsv",sep='\t',header=True)
df2.write.orc("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/",mode='append')
display(df2)

# %%
df3 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower.log",sep='|',header=True)
df3.write.json("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/",mode='append')
df3.show(1)

# %%
df2 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage.tsv",sep='\t',header=True)
df2.write.option("compression","snappy").json("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/",mode='append')
display(df2)

# %%
df1 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer.csv",sep=',')
df1.write.option("compression","gzip").parquet("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/",mode='overwrite')
display(df1)

# %%
df2 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage.tsv",sep='\t',header=True)
df2.write.parquet("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/",mode='error')
display(df2)

# %%
df3 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower.log",sep='|',header=True)
df3.write.option("compression","gzip").parquet("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower_Parquet",mode='append')
df4 = spark.read.parquet("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower_Parquet")
display(df4)

# %%
df1 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer.csv",sep=',')
df1.write.orc("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/",mode='overwrite')
display(df1)

# %%
df2 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage.tsv",sep='\t')
df2.write.orc("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/", mode='append')
display(df2)

# %%
df3 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower.log",sep='|',header=True)
df3.write.orc("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/",mode='append')

# %%
df4 =  spark.read.orc("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/part-00000-tid-2347586235684925256-a54d259c-417b-4b35-a322-3ff1f0560a3c-219-1-c000.snappy.orc")
display(df4)

# %%
df1 = spark.read.orc("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/")
df1.write.format("delta").save("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer_delta",mode='overwrite')

# %%
df2 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage.tsv",sep='\t')
df2.write.format("delta").save("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage_delta", mode='append')
display(df2)

# %%
df3 = spark.read.csv("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower.log",sep='|',header=True)
df3.write.format("delta").save("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/tower/tower_Delta",mode='append')

# %%
df3 = spark.read.format("delta").load("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage_delta", mode='append')
display(df3)

# %%
df1 = spark.read.format("delta").load("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/customer/customer_delta")
df1.write.saveAsTable("telecom_catalog_assign.landing_zone.customer_table")

# %%
df1 = spark.read.format("delta").option("mode","overwrite").load("/Volumes/telecom_catalog_assign/landing_zone/landing_vol/usage/usage_delta")
df1.write.saveAsTable("telecom_catalog_assign.landing_zone.usage_table")

# %%
spark.sql("DROP TABLE telecom_catalog_assign.landing_zone.customer_table")

# %%
spark.sql("SELECT * FROM telecom_catalog_assign.landing_zone.usage_table").show()
