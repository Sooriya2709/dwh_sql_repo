# %%
# %sql

CREATE TABLE lakehousecat1.deltadb.customer_txn (
    txn_id INT,
    customer_id INT,
    region STRING,
    txn_amount DOUBLE,
    txn_type STRING,
    transaction_date DATE
)
USING DELTA;

# %%
# %sql
INSERT INTO lakehousecat1.deltadb.customer_txn VALUES
 (1, 1001, 'North', 250.00, 'Online', '2025-10-01'),
 (2, 1002, 'South', 400.00, 'Offline', '2025-10-02'),
 (3, 1003, 'West', 600.00, 'Online', '2025-10-03');

# %%
# %sql
INSERT INTO lakehousecat1.deltadb.customer_txn VALUES
 (4, 1001, 'North', 300.00, 'Offline', '2025-10-01'),
 (5, 1004, 'East', 750.00, 'Online', '2025-10-02'),
 (6, 1005, 'South', 180.00, 'Online', '2025-10-03');

# %%
# %sql
INSERT INTO lakehousecat1.deltadb.customer_txn VALUES
 (7, 1001, 'North', 270.00, 'Online', '2025-10-01'),
 (8, 1003, 'West', 500.00, 'Offline', '2025-10-02'),
 (9, 1002, 'South', 900.00, 'Online', '2025-10-03');

# %%
# %sql
select * from lakehousecat1.deltadb.customer_txn where region='North';

# %%
# %sql
optimize lakehousecat1.deltadb.customer_txn;

# %%
# %sql
optimize lakehousecat1.deltadb.customer_txn zorder by transaction_date;

# %%
# %sql
optimize lakehousecat1.deltadb.customer_txn

# %%
# %sql
describe detail lakehousecat1.deltadb.customer_txn

# %%
# %sql
SELECT * 
FROM lakehousecat1.deltadb.customer_txn
WHERE region = 'North'
AND transaction_date BETWEEN '2025-10-01' AND '2025-10-03';
