# %%
# Step 1: Prepare sample transaction data
from pyspark.sql.types import StructType, StructField, StringType

from pyspark.sql import Row

data = [
    Row(emp_id=1, emp_name="Venkat", dept="HR", salary=50000),
    Row(emp_id=2, emp_name="Sathish", dept="Finance", salary=60000),
    Row(emp_id=3, emp_name="Jay", dept="IT", salary=70000)
]
df_txn = spark.createDataFrame(data)
display(df_txn)

# %%
# Step 2: Write Data as Delta Files (not table)

# Save as Delta format in the given path
df_txn.write.format("delta").mode("overwrite").save("/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint")

# Verify the data written
df_verify = spark.read.format("delta").load("/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint")
display(df_verify)

# %%
delta_path = "/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint"

# Overwrite existing data
df_verify.write.format("delta").mode("overwrite").save(delta_path)

print(" Data written to Delta path:", delta_path)

# %%
# %sql
-- Step 4: Update record directly using Delta path (no table)
UPDATE delta.`/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint`
SET salary = 55000
WHERE emp_name = 'Sathish';

# %%
# %sql
-- Step 4: Update record directly using Delta path (no table)
UPDATE delta.`/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint`
SET salary = 82000
WHERE emp_name = 'Venkat';

# %%
# %sql
-- Step 5: Delete record directly using Delta path (no table)
DELETE FROM delta.`/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint`
WHERE emp_name = 'Jay';

# %%
# %sql
-- Step 6: Verify Data After Update/Delete
SELECT * FROM delta.`/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint`;

# %%
# %sql
DESC HISTORY delta.`/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint`;

# %%
# %sql
ALTER TABLE delta.`/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint`
SET TBLPROPERTIES ('delta.checkpointInterval' = '3');

# %%
# %sql
-- Step 4: Update record directly using Delta path (no table)
UPDATE delta.`/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint`
SET salary = 905000
WHERE emp_name = 'Venkat';

# %%
# %sql
DESC HISTORY delta.`/Volumes/lakehousecat1/deltadb/datalake/dept_checkpoint`;
