# %%
# %sql
optimize datalake_prod.datalake_prod_schema.silver_shipments zorder by shipment_id,source_city

# %%
# %sql
Create table datalake_prod.datalake_prod_schema.gold_curated_table
using delta partitioned by(origin_hub_city)
(
   select  *
   from datalake_prod.datalake_prod_schema.core_curated_tbl
)

# %%
# %sql
select * from datalake_prod.datalake_prod_schema.gold_curated_table where origin_hub_city='Newyork'

# %%
# %sql
explain select * from datalake_prod.datalake_prod_schema.gold_curated_table where origin_hub_city='Newyork'

# %%
# %sql
VACUUM lakehousecat1.deltadb.product_inventory retain 168 hours

# %%
# %sql
Describe history lakehousecat1.deltadb.product_inventory

# %%
# %sql
create or replace table datalake_prod.datalake_prod_schema.silver_shipments cluster by(shipment_id) AS select * from datalake_prod.datalake_prod_schema.silver_shipments;

# %%
# %sql
describe history datalake_prod.datalake_prod_schema.silver_shipments

# %%
# %sql
create table datalake_prod.datalake_prod_schema.gold_curated_table_testing
shallow clone datalake_prod.datalake_prod_schema.gold_curated_table

# %%
# %sql
RESTORE TABLE datalake_prod.datalake_prod_schema.gold_curated_table TO VERSION AS OF 1

# %%
DESCRIBE HISTORY datalake_prod.datalake_prod_schema.gold_curated_table
